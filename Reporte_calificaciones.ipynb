# %%
estudiantes = []

# Ingresar los datos de 15 estudiantes
for i in range(15):
    nombre = input(f"Ingrese el nombre del estudiante {i + 1}: ")

    # Inicializamos las tres notas con una validación de entrada
    notas = []
    for j in range(1, 4):
        while True:
            try:
                nota = float(input(f"Ingrese la nota {j} de {nombre}: "))
                if 0 <= nota <= 100:  # Aseguramos que la nota esté en el rango 0-100
                    notas.append(nota)
                    break
                else:
                    print("La nota debe estar entre 0 y 100. Inténtalo de nuevo.")
            except ValueError:
                print("Entrada inválida. Por favor, ingrese un número.")

    # Guardamos los datos del estudiante y sus notas
    estudiantes.append({
        "nombre": nombre,
        "notas": notas
    })

# Reporte de calificaciones
print("\n--- Reporte de calificaciones ---")
for estudiante in estudiantes:
    nombre = estudiante["nombre"]
    notas = estudiante["notas"]

    # Verificamos si todas las notas son 70 o más
    if all(nota >= 70 for nota in notas):
        promedio = sum(notas) / 3  # Calculamos el promedio si todas las notas son aprobadas
    else:
        promedio = "NA"  # No acreditado si alguna nota es menor a 70

    # Imprimimos el reporte para cada estudiante
    print(f"Estudiante: {nombre}")
    print(f"Notas: {notas[0]}, {notas[1]}, {notas[2]}")
    print(f"Promedio: {promedio}")
    print("-----------------------------")
# Out:
# Ingrese el nombre del estudiante 1: Maria
# Ingrese la nota 1 de Maria: 90
# Ingrese la nota 2 de Maria: 100
# Ingrese la nota 3 de Maria: 75
# Ingrese el nombre del estudiante 2: Dana
# Ingrese la nota 1 de Dana: 72
# Ingrese la nota 2 de Dana: 80
# Ingrese la nota 3 de Dana: 95
# Ingrese el nombre del estudiante 3: Santiago
# Ingrese la nota 1 de Santiago: 60
# Ingrese la nota 2 de Santiago: 88
# Ingrese la nota 3 de Santiago: 72
# Ingrese el nombre del estudiante 4: Karol
# Ingrese la nota 1 de Karol: 22
# Ingrese la nota 2 de Karol: 60
# Ingrese la nota 3 de Karol: 95
# Ingrese el nombre del estudiante 5: Sofia
# Ingrese la nota 1 de Sofia: 98
# Ingrese la nota 2 de Sofia: 75
# Ingrese la nota 3 de Sofia: 80
# Ingrese el nombre del estudiante 6: Sebastian
# Ingrese la nota 1 de Sebastian: 84
# Ingrese la nota 2 de Sebastian: 90
# Ingrese la nota 3 de Sebastian: 72
# Ingrese el nombre del estudiante 7: Laura
# Ingrese la nota 1 de Laura: 70
# Ingrese la nota 2 de Laura: 55
# Ingrese la nota 3 de Laura: 90
# Ingrese el nombre del estudiante 8: Jose
# Ingrese la nota 1 de Jose: 80
# Ingrese la nota 2 de Jose: 74
# Ingrese la nota 3 de Jose: 92
# Ingrese el nombre del estudiante 9: Juan
# Ingrese la nota 1 de Juan: 60
# Ingrese la nota 2 de Juan: 90
# Ingrese la nota 3 de Juan: 45
# Ingrese el nombre del estudiante 10: Martin
# Ingrese la nota 1 de Martin: 10
# Ingrese la nota 2 de Martin: 35
# Ingrese la nota 3 de Martin: 80
# Ingrese el nombre del estudiante 11: Andres
# Ingrese la nota 1 de Andres: 95
# Ingrese la nota 2 de Andres: 71
# Ingrese la nota 3 de Andres: 100
# Ingrese el nombre del estudiante 12: Juliana
# Ingrese la nota 1 de Juliana: 95
# Ingrese la nota 2 de Juliana: 82
# Ingrese la nota 3 de Juliana: 77
# Ingrese el nombre del estudiante 13: Camila
# Ingrese la nota 1 de Camila: 68
# Ingrese la nota 2 de Camila: 80
# Ingrese la nota 3 de Camila: 72
# Ingrese el nombre del estudiante 14: Sara
# Ingrese la nota 1 de Sara: 80
# Ingrese la nota 2 de Sara: 95
# Ingrese la nota 3 de Sara: 100
# Ingrese el nombre del estudiante 15: David
# Ingrese la nota 1 de David: 75
# Ingrese la nota 2 de David: 100
# Ingrese la nota 3 de David: 80
#
# --- Reporte de calificaciones ---
# Estudiante: Maria
# Notas: 90.0, 100.0, 75.0
# Promedio: 88.33333333333333
# -----------------------------
# Estudiante: Dana
# Notas: 72.0, 80.0, 95.0
# Promedio: 82.33333333333333
# -----------------------------
# Estudiante: Santiago
# Notas: 60.0, 88.0, 72.0
# Promedio: NA
# -----------------------------
# Estudiante: Karol
# Notas: 22.0, 60.0, 95.0
# Promedio: NA
# -----------------------------
# Estudiante: Sofia
# Notas: 98.0, 75.0, 80.0
# Promedio: 84.33333333333333
# -----------------------------
# Estudiante: Sebastian
# Notas: 84.0, 90.0, 72.0
# Promedio: 82.0
# -----------------------------
# Estudiante: Laura
# Notas: 70.0, 55.0, 90.0
# Promedio: NA
# -----------------------------
# Estudiante: Jose
# Notas: 80.0, 74.0, 92.0
# Promedio: 82.0
# -----------------------------
# Estudiante: Juan
# Notas: 60.0, 90.0, 45.0
# Promedio: NA
# -----------------------------
# Estudiante: Martin
# Notas: 10.0, 35.0, 80.0
# Promedio: NA
# -----------------------------
# Estudiante: Andres
# Notas: 95.0, 71.0, 100.0
# Promedio: 88.66666666666667
# -----------------------------
# Estudiante: Juliana
# Notas: 95.0, 82.0, 77.0
# Promedio: 84.66666666666667
# -----------------------------
# Estudiante: Camila
# Notas: 68.0, 80.0, 72.0
# Promedio: NA
# -----------------------------
# Estudiante: Sara
# Notas: 80.0, 95.0, 100.0
# Promedio: 91.66666666666667
# -----------------------------
# Estudiante: David
# Notas: 75.0, 100.0, 80.0
# Promedio: 85.0
# -----------------------------
